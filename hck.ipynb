# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train=pd.read_csv('C:\\Users\\User\\Documents\\6a62a5b4967411ea\\Dataset\\train.csv')

# %%
test=pd.read_csv('C:\\Users\\User\\Documents\\6a62a5b4967411ea\\Dataset\\test.csv')

# %%
train.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE
# 0   174   1.0    92    29    36                 0
# 1   236   1.0   103   142    34                 1
# 2   174   1.0   110    93    34                 1
# 3   249   1.0    72    29    34                 1
# 4   174   0.0   112    29    43                 1

# %%
train['DATE']=pd.to_datetime(train.DATE)

# %%
train['YEAR']=train['DATE'].dt.year

# %%
train['MONTH']=train['DATE'].dt.month

# %%
train['DAY']=train['DATE'].dt.day

# %%
train.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  ...  X_10  \
# 0   CR_102659 2004-07-04    0   36   34    2    1    5    6    1  ...     1
# 1   CR_189752 2017-07-18    1   37   37    0    0   11   17    1  ...     1
# 2   CR_184637 2017-03-15    0    3    2    3    5    1    0    2  ...     1
# 3   CR_139071 2009-02-13    0   33   32    2    1    7    1    1  ...     1
# 4   CR_109335 2005-04-13    0   33   32    2    1    8    3    0  ...     1
#
#    X_11  X_12  X_13  X_14  X_15  MULTIPLE_OFFENSE  YEAR  MONTH  DAY
# 0   174   1.0    92    29    36                 0  2004      7    4
# 1   236   1.0   103   142    34                 1  2017      7   18
# 2   174   1.0   110    93    34                 1  2017      3   15
# 3   249   1.0    72    29    34                 1  2009      2   13
# 4   174   0.0   112    29    43                 1  2005      4   13
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(17,7))
ax=sns.heatmap(train.corr(),annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (19.0, 0.0)

# %%
train.corr()['MULTIPLE_OFFENSE'].sort_values()
# Out:
# X_10               -0.242596
# X_12               -0.113061
# X_8                -0.033397
# X_2                -0.027293
# X_3                -0.027218
# X_14               -0.015267
# X_7                -0.008036
# X_6                -0.007903
# X_5                -0.003450
# X_4                -0.002921
# YEAR               -0.002755
# X_9                -0.000748
# DAY                 0.004736
# X_13                0.006512
# MONTH               0.006736
# X_1                 0.014034
# X_15                0.044916
# X_11                0.105088
# MULTIPLE_OFFENSE    1.000000
# Name: MULTIPLE_OFFENSE, dtype: float64

# %%
def plot(feature_x,target='MULTIPLE_OFFENSE'):
    sns.catplot(y=feature_x,x=target,kind='bar',data=train)
    sns.catplot(y=feature_x,x=target,kind='box',data=train)
    sns.catplot(y=feature_x,x=target,kind='swarm',data=train)

# %%
sns.catplot(y='MONTH',x='MULTIPLE_OFFENSE',kind='box',data=train)

# %%
sns.countplot(x='MULTIPLE_OFFENSE',data=train)

# %%
sns.boxplot(y='MONTH',x='MULTIPLE_OFFENSE',data=train)

# %%
sns.boxplot(y='DAY',x='MULTIPLE_OFFENSE',data=train)

# %%
sns.boxplot(y='YEAR',x='MULTIPLE_OFFENSE',data=train)

# %%
plt.figure(figsize=(17,7))
sns.countplot("YEAR", hue="MULTIPLE_OFFENSE", data=train)

# %%
train.isnull().sum()
# Out:
# INCIDENT_ID           0
# DATE                  0
# X_1                   0
# X_2                   0
# X_3                   0
# X_4                   0
# X_5                   0
# X_6                   0
# X_7                   0
# X_8                   0
# X_9                   0
# X_10                  0
# X_11                  0
# X_12                182
# X_13                  0
# X_14                  0
# X_15                  0
# MULTIPLE_OFFENSE      0
# YEAR                  0
# MONTH                 0
# DAY                   0
# dtype: int64

# %%
train['X_12'].value_counts()
# Out:
# 1.0     15674
# 0.0      5171
# 2.0      2039
# 3.0       476
# 4.0       176
# 5.0        59
# 6.0        36
# 8.0         9
# 10.0        7
# 9.0         6
# 7.0         4
# 11.0        4
# 15.0        2
# 20.0        2
# 17.0        1
# 58.0        1
# 50.0        1
# 40.0        1
# 16.0        1
# 90.0        1
# 12.0        1
# 30.0        1
# 14.0        1
# Name: X_12, dtype: int64

# %%
train['X_10'].value_counts()
# Out:
# 1     20198
# 2      2695
# 3       549
# 4       225
# 5        71
# 6        54
# 8        15
# 10       14
# 9         7
# 7         7
# 11        4
# 12        3
# 20        2
# 15        2
# 30        1
# 22        1
# 19        1
# 40        1
# 50        1
# 18        1
# 58        1
# 17        1
# 90        1
# 16        1
# Name: X_10, dtype: int64

# %%
train.describe(include=['object','bool'])
# Out:
#        INCIDENT_ID
# count        23856
# unique       23856
# top        CR_8728
# freq             1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 21 columns):
# INCIDENT_ID         23856 non-null object
# DATE                23856 non-null datetime64[ns]
# X_1                 23856 non-null int64
# X_2                 23856 non-null int64
# X_3                 23856 non-null int64
# X_4                 23856 non-null int64
# X_5                 23856 non-null int64
# X_6                 23856 non-null int64
# X_7                 23856 non-null int64
# X_8                 23856 non-null int64
# X_9                 23856 non-null int64
# X_10                23856 non-null int64
# X_11                23856 non-null int64
# X_12                23674 non-null float64
# X_13                23856 non-null int64
# X_14                23856 non-null int64
# X_15                23856 non-null int64
# MULTIPLE_OFFENSE    23856 non-null int64
# YEAR                23856 non-null int64
# MONTH               23856 non-null int64
# ...

# %%
train=train.drop('DATE',axis=1)

# %%
train=train.drop('INCIDENT_ID',axis=1)

# %%
train['X_12']=train['X_12'].fillna(0)

# %%
train.X_12=train.X_12.astype('int64')

# %%
X=train.drop('MULTIPLE_OFFENSE',axis=1).values
y=train['MULTIPLE_OFFENSE'].values

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
Scaler=MinMaxScaler()

# %%
X_train.shape
# Out:
# (16699, 18)

# %%
X_test.shape
# Out:
# (7157, 18)

# %%
X.shape
# Out:
# (23856, 18)

# %%
X_train=Scaler.fit_transform(X_train)
X_test=Scaler.transform(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
pred=model.predict(X_test)
print(classification_report(y_test,pred))
print(confusion_matrix(y_test,pred))
# Out:
# F:\ANACONDARAJ\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#               precision    recall  f1-score   support
#
#            0       0.57      0.01      0.02       322
#            1       0.96      1.00      0.98      6835
#
#     accuracy                           0.96      7157
#    macro avg       0.76      0.51      0.50      7157
# weighted avg       0.94      0.96      0.93      7157
#
# [[   4  318]
#  [   3 6832]]

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(X_train,y_train)
pedict_tree=tree.predict(X_test)
print(classification_report(y_test,pedict_tree))
print(confusion_matrix(y_test,pedict_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97       322
#            1       1.00      1.00      1.00      6835
#
#     accuracy                           1.00      7157
#    macro avg       0.99      0.98      0.98      7157
# weighted avg       1.00      1.00      1.00      7157
#
# [[ 309   13]
#  [   6 6829]]

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.svm import SVC
svc=SVC(C=1.0,gamma='auto',kernel='rbf')#rbf=0.87#linear=0.83
svc.fit(X_train,y_train)
pred_svc=svc.predict(X_test)
print(classification_report(y_test,pred_svc))
print(confusion_matrix(y_test,pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       322
#            1       0.96      1.00      0.98      6835
#
#     accuracy                           0.96      7157
#    macro avg       0.48      0.50      0.49      7157
# weighted avg       0.91      0.96      0.93      7157
#
# [[   0  322]
#  [   0 6835]]

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'kernel':('linear', 'rbf'), 'C':[1,10,100],'gamma':[0.0001,0.00001,0.00004]}
# parameters=[{'C':[1,10,100,1000],'kernel': ['linear']},
#            {'C':[1,10,100,1000],'kernel': ['rbf'],'gamma':[0.01,0.001,0.0001,0.00004]}
#            ]
grid_search=GridSearchCV(estimator=svc,param_grid=parameters,n_jobs=-1,cv=10,scoring='accuracy')
grid_search.fit(X_train,y_train)

# %%
grid_search.best_params_
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
1/len(train)*100
# Out:
# 0.0041918175720992625
